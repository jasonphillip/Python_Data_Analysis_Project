# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib 
import seaborn as sns

df_og= pd.read_csv('layoffs.csv')
df = df_og
df.head()
# Out:
#       company       location   industry  total_laid_off  percentage_laid_off  \
# 0      Amazon        Seattle     Retail          8000.0                 0.02
# 1  Salesforce    SF Bay Area      Sales          8000.0                 0.10
# 2       Vimeo  New York City   Consumer             NaN                 0.11
# 3     Harappa      New Delhi  Education            60.0                 0.30
# 4   ByteDance       Shanghai   Consumer             NaN                 0.10
#
#          date     stage        country  funds_raised
# 0  2023-01-04       IPO  United States         108.0
# 1  2023-01-04       IPO  United States          65.0
# 2  2023-01-04       IPO  United States         450.0
# 3  2023-01-03  Acquired          India           NaN
# 4  2023-01-03   Unknown          China        9400.0

# %%
df.shape
# Out:
# (1860, 9)

# %%
df.describe().T
# Out:
#                       count        mean          std  min   25%     50%  \
# total_laid_off       1295.0  205.196139   632.737529  3.0  32.0   70.00
# percentage_laid_off  1255.0    0.271408     0.262939  0.0   0.1    0.18
# funds_raised         1719.0  851.297438  6184.568059  0.0  45.0  139.00
#
#                         75%       max
# total_laid_off       150.00   11000.0
# percentage_laid_off    0.31       1.0
# funds_raised         405.50  121900.0

# %%
df3.dtypes
# Out:
# company                        object
# location                       object
# industry                       object
# total_laid_off                  int64
# percentage_laid_off           float64
# date                   datetime64[ns]
# stage                          object
# country                        object
# funds_raised                   object
# month                           int64
# year                            int64
# total_employees               float64
# dtype: object

# %%
# look for NA's
df2.isna().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off         277
# percentage_laid_off    317
# date                     0
# stage                    0
# country                  0
# funds_raised             0
# month                    0
# year                     0
# dtype: int64

# %%
# check for duplicates
df[df.duplicated()]
# Out:
#      company location        industry  total_laid_off  percentage_laid_off  \
# 1003   Cazoo   London  Transportation           750.0                 0.15
#
#             date stage         country  funds_raised
# 1003  2022-06-07   IPO  United Kingdom        2000.0

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
#               company        location     industry  total_laid_off  \
# 2               Vimeo   New York City     Consumer             NaN
# 3             Harappa       New Delhi    Education            60.0
# 4           ByteDance        Shanghai     Consumer             NaN
# 5            Bilibili        Shanghai        Media             NaN
# 6     Octopus Network     Beau Vallon       Crypto             NaN
# ...               ...             ...          ...             ...
# 1849            Popin   New York City      Fitness             NaN
# 1850    Tuft & Needle         Phoenix       Retail             NaN
# 1854          Service     Los Angeles       Travel             NaN
# 1858         EasyPost  Salt Lake City    Logistics            75.0
# 1859        Homebound     SF Bay Area  Real Estate             NaN
#
#       percentage_laid_off        date     stage        country  funds_raised
# 2                    0.11  2023-01-04       IPO  United States         450.0
# ...

# %%
# Deal with industry Naans by doing a quick google search
df[df['industry'].isnull()]
# Out:
#         company       location industry  total_laid_off  percentage_laid_off  \
# 107   DataRails       Tel Aviv      NaN            30.0                 0.18
# 139    Motional         Boston      NaN             NaN                  NaN
# 151   Proton.ai         Boston      NaN             NaN                  NaN
# 261  InfluxData    SF Bay Area      NaN            65.0                 0.27
# 275   AvantStay    Los Angeles      NaN           144.0                 0.22
# 306      Exodus  Nebraska City      NaN            59.0                 0.22
#
#            date           stage        country  funds_raised
# 107  2022-12-05        Series B         Israel         103.0
# 139  2022-11-30         Unknown  United States           NaN
# 151  2022-11-29        Series A  United States          20.0
# 261  2022-11-10        Series D  United States         119.0
# 275  2022-11-09  Private Equity  United States         686.0
# 306  2022-11-04         Unknown  United States          60.0

# %%
df.industry.unique()
# Out:
# array(['Retail', 'Sales', 'Consumer', 'Education', 'Media', 'Crypto',
#        'Finance', 'Real Estate', 'Hardware', 'Transportation', 'Other',
#        'Food', 'Healthcare', 'Data', 'Support', 'HR', 'Product',
#        'Infrastructure', 'Marketing', 'Security', 'Legal', 'Construction',
#        nan, 'Travel', 'Fitness', 'Recruiting', 'Energy', 'Logistics',
#        'Aerospace'], dtype=object)

# %%
# filling in industry NA's with correct data
df.loc[df['company']=='DataRails','industry'] = 'Finance'
df.loc[df['company']=='Motional','industry'] = 'Transportation'
df.loc[df['company']=='Proton.ai','industry'] = 'Sales'
df.loc[df['company']=='InfluxData','industry'] = 'Product'
df.loc[df['company']=='AvantStay','industry'] = 'Travel'
df.loc[df['company']=='Exodus','industry'] = 'Crypto'

# %%
# Filling in stage column NA's with unknown
df['stage'] = df['stage'].fillna('Unknown')

# %%
df[df['date'].isnull()]
# Out:
#         company     location     industry  total_laid_off  \
# 1859  Homebound  SF Bay Area  Real Estate             NaN
#
#       percentage_laid_off date    stage        country  funds_raised
# 1859                  NaN  NaN  Unknown  United States         128.0

# %%
# removing Homebound row with too many NA'
df = df[df.company != 'Homebound']

# %%
# Filling in funds_raised column NA's with unknown
df['funds_raised'] = df['funds_raised'].fillna('Unknown')

# %%
df[df['funds_raised'].isnull()]
# Out:
# Empty DataFrame
# Columns: [company, location, industry, total_laid_off, percentage_laid_off, date, stage, country, funds_raised]
# Index: []

# %%
# convert date column to panda datetime series and add month and column rows
df['date'] = df['date'].apply(pd.to_datetime)
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
# companies that had more than one round of layoffs
df.company.value_counts().loc[lambda x: x<1]
# Out:
# Series([], Name: company, dtype: int64)

# %%
print(df.loc[df['company'].isin(['SpotHero'])])
# Out:
#        company location        industry  total_laid_off  percentage_laid_off  \
# 1349  SpotHero  Chicago  Transportation            40.0                 0.21
# 1826  SpotHero  Chicago  Transportation             NaN                  NaN
#
#            date     stage        country funds_raised  month  year
# 1349 2020-06-03  Series D  United States        117.0      6  2020
# 1826 2020-03-24  Series D  United States        117.0      3  2020

# %%
data = data[~(data.total_laid_off.isnull())]
data.total_laid_off = data.total_laid_off.astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [152], in <cell line: 1>()
# ----> 1 data = data[~(data.total_laid_off.isnull())]
#       2 data.total_laid_off = data.total_laid_off.astype(int)
#
# NameError: name 'data' is not defined

# %%
# removing all rows that have NA in both columns(total_laid_off and percentage_laid_off)

df2 = df[~(df.isnull().sum(axis=1) == 2)]
df2
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             NaN
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             NaN
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             NaN
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
df
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             NaN
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             NaN
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             NaN
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
df2[df2.company == "Lola"]
# Out:
#      company location industry  total_laid_off  percentage_laid_off  \
# 1847    Lola   Boston   Travel            34.0                  NaN
#
#            date     stage        country funds_raised  month  year
# 1847 2020-03-19  Series C  United States         81.0      3  2020

# %%
df2[df2.isnull().sum(axis=1) == 1]
# Out:
#               company        location        industry  total_laid_off  \
# 2               Vimeo   New York City        Consumer             NaN
# 4           ByteDance        Shanghai        Consumer             NaN
# 5            Bilibili        Shanghai           Media             NaN
# 6     Octopus Network     Beau Vallon          Crypto             NaN
# 9              Zoopla          London     Real Estate            50.0
# ...               ...             ...             ...             ...
# 1844           Bounce       Bengaluru  Transportation           120.0
# 1847             Lola          Boston          Travel            34.0
# 1849            Popin   New York City         Fitness             NaN
# 1854          Service     Los Angeles          Travel             NaN
# 1858         EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage         country funds_raised  \
# ...

# %%
top_companies = df.nlargest(11,['total_laid_off'])

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_companies.company, y=top_companies.total_laid_off)
plt.title("Top companies interms of Layoffs", fontsize=15, fontweight='bold')
plt.xlabel("Companies")
plt.ylabel("No of Layoffs")
plt.show()

# %%
df3.total_laid_off = df3.total_laid_off.astype(int)
df3
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail            8000
# 1        Salesforce     SF Bay Area           Sales            8000
# 2             Vimeo   New York City        Consumer               0
# 3           Harappa       New Delhi       Education              60
# 4         ByteDance        Shanghai        Consumer               0
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel               0
# 1855   HopSkipDrive     Los Angeles  Transportation               8
# 1856    Panda Squad     SF Bay Area        Consumer               6
# 1857  Tamara Mellon     Los Angeles          Retail              20
# 1858       EasyPost  Salt Lake City       Logistics              75
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
# going to fill NA with 0 in total_laid_off and percentage_laid_off

df3 = df2.fillna(0)

df3
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             0.0
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             0.0
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             0.0
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
df3.isna().sum()
# Out:
# company                0
# location               0
# industry               0
# total_laid_off         0
# percentage_laid_off    0
# date                   0
# stage                  0
# country                0
# funds_raised           0
# month                  0
# year                   0
# dtype: int64

# %%
df2
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             NaN
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             NaN
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             NaN
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
df2
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             NaN
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             NaN
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             NaN
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
# create total number of employees column

df3['total_employees'] = df3['total_laid_off'] /df3['percentage_laid_off']
df3
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             0.0
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             0.0
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             0.0
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
sum(df3['total_employees']==0)
# Out:
# 277

# %%
df3[df3.company == "Uber"]
# Out:
#      company     location        industry  total_laid_off  \
# 515     Uber      Vilnius  Transportation            60.0
# 1336    Uber    Amsterdam  Transportation           225.0
# 1368    Uber    Bengaluru  Transportation           600.0
# 1387    Uber  SF Bay Area  Transportation          3000.0
# 1432    Uber  SF Bay Area  Transportation          3700.0
#
#       percentage_laid_off       date stage        country funds_raised  month  \
# 515                  0.00 2022-09-07   IPO      Lithuania      24700.0      9
# 1336                 0.25 2020-06-12   IPO    Netherlands      24700.0      6
# 1368                 0.23 2020-05-26   IPO          India      24700.0      5
# 1387                 0.13 2020-05-18   IPO  United States      24700.0      5
# 1432                 0.14 2020-05-06   IPO  United States      24700.0      5
#
#       year  total_employees
# 515   2022              inf
# 1336  2020     9.000000e+02
# 1368  2020     2.608696e+03
# 1387  2020     2.307692e+04
# ...

# %%
df3.stage.value_counts()
# Out:
# Unknown           258
# IPO               237
# Series B          223
# Series C          209
# Series D          178
# Series A          123
# Acquired          100
# Series E           85
# Seed               49
# Series F           43
# Private Equity     26
# Series H           18
# Series G           10
# Series I            6
# Series J            6
# Name: stage, dtype: int64

# %%
df3.location.value_counts()
# Out:
# SF Bay Area      414
# New York City    176
# Boston            72
# Los Angeles       64
# Bengaluru         57
#                 ...
# Ferdericton        1
# Dakar              1
# Florianópolis      1
# Shenzen            1
# Tampa Bay          1
# Name: location, Length: 143, dtype: int64

# %%
df3.country.value_counts()
# Out:
# United States           1021
# India                    106
# Canada                    76
# Brazil                    54
# Germany                   48
# United Kingdom            46
# Israel                    37
# Australia                 30
# Singapore                 22
# Indonesia                 19
# Sweden                    14
# China                     10
# United Arab Emirates       6
# Netherlands                6
# Nigeria                    6
# Kenya                      6
# Argentina                  5
# Hong Kong                  4
# Denmark                    4
# Estonia                    4
# Mexico                     4
# Ireland                    3
# Austria                    3
# Vietnam                    3
# Pakistan                   3
# Malaysia                   3
# Seychelles                 3
# Norway                     2
# Portugal                   2
# Luxembourg                 2
# Romania                    2
# Colombia                   2
# ...

# %%
df.country.value_counts()
# Out:
# United States           1218
# India                    113
# Canada                    84
# United Kingdom            58
# Brazil                    57
# Germany                   53
# Israel                    43
# Australia                 36
# Singapore                 29
# Indonesia                 23
# Sweden                    17
# China                     14
# Nigeria                   10
# United Arab Emirates       6
# Kenya                      6
# Netherlands                6
# Hong Kong                  5
# Argentina                  5
# Mexico                     4
# Seychelles                 4
# Ireland                    4
# Denmark                    4
# Estonia                    4
# Norway                     4
# Austria                    3
# Pakistan                   3
# Vietnam                    3
# Malaysia                   3
# Colombia                   3
# Luxembourg                 3
# Chile                      2
# New Zealand                2
# ...

# %%
df3.industry.value_counts()
# Out:
# Finance           200
# Retail            130
# Healthcare        119
# Marketing         101
# Transportation    100
# Food               95
# Real Estate        91
# Consumer           78
# Other              67
# Education          67
# Media              65
# Crypto             61
# Travel             53
# Data               46
# Security           45
# HR                 39
# Logistics          31
# Product            27
# Infrastructure     27
# Sales              26
# Recruiting         24
# Fitness            23
# Support            20
# Construction       12
# Energy              9
# Legal               8
# Aerospace           5
# Hardware            2
# Name: industry, dtype: int64

# %%
df.industry.value_counts()
# Out:
# Finance           233
# Retail            153
# Healthcare        134
# Transportation    117
# Food              116
# Marketing         114
# Real Estate       104
# Consumer           91
# Other              83
# Education          81
# Media              77
# Crypto             73
# Travel             63
# Data               61
# Security           55
# HR                 47
# Infrastructure     36
# Logistics          35
# Product            30
# Sales              29
# Recruiting         28
# Fitness            27
# Support            27
# Construction       14
# Energy             11
# Legal               9
# Aerospace           6
# Hardware            4
# Name: industry, dtype: int64

# %%
corr_matrix =df3.corr()

# %%
df2
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             NaN
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             NaN
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             NaN
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
sum(df.total_laid_off)
# Out:
# nan

# %%
sum(df3.total_laid_off)
# Out:
# 264979.0

# %%
sum(df.total_laid_off.fillna(0))
# Out:
# 264979.0

# %%
df.head(20)
# Out:
#             company       location        industry  total_laid_off  \
# 0            Amazon        Seattle          Retail          8000.0
# 1        Salesforce    SF Bay Area           Sales          8000.0
# 2             Vimeo  New York City        Consumer             NaN
# 3           Harappa      New Delhi       Education            60.0
# 4         ByteDance       Shanghai        Consumer             NaN
# 5          Bilibili       Shanghai           Media             NaN
# 6   Octopus Network    Beau Vallon          Crypto             NaN
# 7              PayU      Amsterdam         Finance           150.0
# 8       Back Market          Paris          Retail            93.0
# 9            Zoopla         London     Real Estate            50.0
# 10         Qualcomm      San Diego        Hardware           153.0
# 11         TuSimple      San Diego  Transportation           350.0
# 12           Lendis         Berlin           Other             NaN
# ...

# %%
df[df.location == ''].groupby('b').agg({'C': lambda x: x.isnull().sum()})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [179], in <cell line: 1>()
# ----> 1 df[df.location == ''].groupby('b').agg({'C': lambda x: x.isnull().sum()})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
# ...

# %%
temp = df.groupby('location').agg({'percentage_laid_off': lambda x: x.isnull().sum()})

# %%
df3.location.value_counts()

# %%
temp = temp.sort_values(by=['percentage_laid_off'], ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [180], in <cell line: 1>()
# ----> 1 temp = temp.sort_values(by=['percentage_laid_off'], ascending = False)
#
# NameError: name 'temp' is not defined

# %%
temp.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [181], in <cell line: 1>()
# ----> 1 temp.head(20)
#
# NameError: name 'temp' is not defined

# %%
df3
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             0.0
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             0.0
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             0.0
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
df3 = df3.drop('total_employees', axis=1)

# %%
df3
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail          8000.0
# 1        Salesforce     SF Bay Area           Sales          8000.0
# 2             Vimeo   New York City        Consumer             0.0
# 3           Harappa       New Delhi       Education            60.0
# 4         ByteDance        Shanghai        Consumer             0.0
# ...             ...             ...             ...             ...
# 1854        Service     Los Angeles          Travel             0.0
# 1855   HopSkipDrive     Los Angeles  Transportation             8.0
# 1856    Panda Squad     SF Bay Area        Consumer             6.0
# 1857  Tamara Mellon     Los Angeles          Retail            20.0
# 1858       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country funds_raised  \
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
fig = make_subplots(
    rows=3, cols=2,
    subplot_titles=('Company','Location', 'Country','Industry', 'Stage', 'Raised'))

fig.add_trace(go.Histogram(x=df_layoff['company']),row=1, col=1)
fig.add_trace(go.Histogram(x=df_layoff['location']),row=1, col=2)
fig.add_trace(go.Histogram(x=df_layoff['country']),row=2, col=1)
fig.add_trace(go.Histogram(x=df_layoff['industry']),row=2, col=2)
fig.add_trace(go.Histogram(x=df_layoff['stage']),row=3, col=1)
fig.add_trace(go.Histogram(x=df_layoff['funds_raised']),row=3, col=2)
fig.add_trace(go.Histogram(x=df3_USA['location']),row=2, col=1)



fig.update_xaxes(categoryorder='total descending')
fig.update_layout(height=1200,width=1000, showlegend=False, title_text="<b>Row Count: All-data</b>")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [186], in <cell line: 11>()
#       9 fig.add_trace(go.Histogram(x=df_layoff['stage']),row=3, col=1)
#      10 fig.add_trace(go.Histogram(x=df_layoff['funds_raised']),row=3, col=2)
# ---> 11 fig.add_trace(go.Histogram(x=df3_USA['location']),row=2, col=1)
#      15 fig.update_xaxes(categoryorder='total descending')
#      16 fig.update_layout(height=1200,width=1000, showlegend=False, title_text="<b>Row Count: All-data</b>")
#
# NameError: name 'df3_USA' is not defined

# %%
df3_USA = df3.loc[df3['country'] == 'United States']

# %%
df3_USA

# %%
test1 = df3_USA.location.value_counts()

# %%
df3_USA.location == "Melbourne"

# %%
df3_USA.loc[df3_USA['location'] == 'Melbourne']

# %%
test1.head(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [187], in <cell line: 1>()
# ----> 1 test1.head(40)
#
# NameError: name 'test1' is not defined

# %%
df2.isna().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off         277
# percentage_laid_off    317
# date                     0
# stage                    0
# country                  0
# funds_raised             0
# month                    0
# year                     0
# dtype: int64

# %%
df_og.isna().sum()
# Out:
# company                  0
# location                 0
# industry                 6
# total_laid_off         565
# percentage_laid_off    605
# date                     1
# stage                    4
# country                  0
# funds_raised           141
# dtype: int64

# %%
conda install geoplot -c conda-forge
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: - ^C
# failed with initial frozen solve. Retrying with flexible solve.
#
# CondaError: KeyboardInterrupt
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge geoplot
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: - ^C
# failed with repodata from current_repodata.json, will retry with next repodata source.
#
# CondaError: KeyboardInterrupt
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import geoplot

print("Geoplot Version : {}".format(geoplot.__version__))

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import geoplot
#       3 print("Geoplot Version : {}".format(geoplot.__version__))
#       5 import matplotlib.pyplot as plt
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geoplot/__init__.py:1, in <module>
# ----> 1 from .geoplot import (
#       2     pointplot, polyplot, choropleth, cartogram, kdeplot, sankey, voronoi, quadtree, webmap,
#       3     __version__
#       4 )
#       5 from .crs import (
#       6     PlateCarree, LambertCylindrical, Mercator, WebMercator, Miller, Mollweide, Robinson,
#       7     Sinusoidal, InterruptedGoodeHomolosine, Geostationary, NorthPolarStereo, SouthPolarStereo,
#    (...)
#      10     EckertI, EckertII, EckertIII, EckertIV, EckertV, EckertVI, NearsidePerspective
#      11 )
#      12 from .datasets import get_path
#
# ...

# %%
pip install geoplot
# Out:
# ...
#   Using cached geoplot-0.5.1-py3-none-any.whl (28 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
alt_paths = [
                # The Framework build from Kyng Chaos
                "/Library/Frameworks/GEOS.framework/Versions/Current/GEOS",
                # macports
                '/opt/local/lib/libgeos_c.dylib',
                # homebrew
                '/usr/local/lib/libgeos_c.dylib',
                # homebrew ARM
                '/opt/homebrew/lib/libgeos_c.dylib',
            ]

# %%
import geoplot
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 import geoplot
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geoplot/__init__.py:1, in <module>
# ----> 1 from .geoplot import (
#       2     pointplot, polyplot, choropleth, cartogram, kdeplot, sankey, voronoi, quadtree, webmap,
#       3     __version__
#       4 )
#       5 from .crs import (
#       6     PlateCarree, LambertCylindrical, Mercator, WebMercator, Miller, Mollweide, Robinson,
#       7     Sinusoidal, InterruptedGoodeHomolosine, Geostationary, NorthPolarStereo, SouthPolarStereo,
#    (...)
#      10     EckertI, EckertII, EckertIII, EckertIV, EckertV, EckertVI, NearsidePerspective
#      11 )
#      12 from .datasets import get_path
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geoplot/geoplot.py:9, in <module>
#       7 import numpy as np
# ...

# %%
pip uninstall geoplot
# Out:
#   Input In [12]
#     pip uninstall geoplot
#         ^
# SyntaxError: invalid syntax

# %%
# pip install --upgrade pip

# %%
export GEOS_LIBRARY_PATH=/opt/homebrew/lib
# Out:
#   Input In [4]
#     export GEOS_LIBRARY_PATH=/opt/homebrew/lib
#            ^
# SyntaxError: invalid syntax

# %%
python -c 'import _ctypes; _ctypes.dlopen("/usr/local/lib/libgdal.dylib")'
# Out:
#   Input In [7]
#     python -c 'import _ctypes; _ctypes.dlopen("/usr/local/lib/libgdal.dylib")'
#               ^
# SyntaxError: invalid syntax
